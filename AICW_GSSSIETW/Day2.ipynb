# %% [markdown]
# <h1>Day 2- AICW Program</h1>

# %% [markdown]
# ### Python basics

# %%
print('Welcome to AICW')
# Out:
# Welcome to AICW

# %%
# create a variable 'name' and assign your name
name="Deepika"

# %%
print(name)
# Out:
# Deepika

# %%
name
# Out:
# 'Deepika'

# %%
type(name)
# Out:
# str

# %%
# creating age variable and assign a value
age=20
print(age)
print(type(age))
# Out:
# 20
# <class 'int'>

# %%
para='''
this is line 1
line2
line3
'''

# %%
print(para)
# Out:
# this is line 1
# line2
# line3

# %%
lst=['AICW','GSSSIETW',22,22,'Metagalli',13.5]

# %%
type(lst)
# Out:
# list

# %%
dir(lst)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
# list-[]-mutable -any data types
# Append 
# tab-suggests the function name 
# shift tab-gives info how to write
lst.append('KRS Road')
lst
# Out:
# ['AICW', 'GSSSIETW', 22, 22, 'Metagalli', 13.5, 'KRS Road', 'KRS Road']

# %%
lst1=lst.copy()
lst1
# Out:
# ['AICW', 'GSSSIETW', 22, 22, 'Metagalli', 13.5, 'KRS Road', 'KRS Road']

# %%
# count function
lst.count(22)
# Out:
# 2

# %%
# extend func
lst2 =['mango','apple','jackfruit','kiwi','cherry']

# %%
lst.extend(lst2)

# %% [markdown]
# lst

# %%
# index
lst1.index('AICW')
# Out:
# 0

# %%
lst1
# Out:
# ['AICW', 'GSSSIETW', 22, 22, 'Metagalli', 13.5, 'KRS Road', 'KRS Road']

# %%
lst1.index(22)
# Out:
# 2

# %%
# insert
lst1.insert(2,2004)

# %%
lst1
# Out:
# ['AICW', 'GSSSIETW', 2004, 22, 22, 'Metagalli', 13.5, 'KRS Road', 'KRS Road']

# %%
# pop 
lst1.pop(-2)
# Out:
# 'KRS Road'

# %%
lst1
# Out:
# ['AICW', 'GSSSIETW', 2004, 22, 22, 'Metagalli', 13.5, 'KRS Road']

# %%
# remove 
lst1.remove(22)

# %%
lst1
# Out:
# ['AICW', 'GSSSIETW', 2004, 22, 'Metagalli', 13.5, 'KRS Road']

# %%
# reverse
lst1.reverse()

# %%
lst1
# Out:
# ['KRS Road', 13.5, 'Metagalli', 22, 2004, 'GSSSIETW', 'AICW']

# %%
# slicing
x='RMS'
x[::-1]
# Out:
# 'SMR'

# %%
#clear
lst1.clear()
lst1
# Out:
# []

# %%
# Tuple -() - immutable - ddts
tup=("Edunet Foundation",2015)
tup
# Out:
# ('Edunet Foundation', 2015)

# %%
type(tup)
# Out:
# tuple

# %%
dir(tup)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
# count 
tup.count(2015)
# Out:
# 1

# %%
tup.index(2015)
# Out:
# 1

# %%
#set - {} - unique
s1={'name','age'}

# %%
type(s1)
# Out:
# set

# %%
s1
# Out:
# {'age', 'name'}

# %%
s2={1,56,90,55,56}

# %%
s2
# Out:
# {1, 55, 56, 90}

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
print(s1)
print(s2)
# Out:
# {'name', 'age'}
# {56, 1, 90, 55}

# %%
s1.union(s2)
# Out:
# {1, 55, 56, 90, 'age', 'name'}

# %%
s1.intersection(s2)
# Out:
# set()

# %%
s3={90,55,2004,2015}
s2.intersection(s3)
# Out:
# {55, 90}

# %%
#dictionary -{}-k:v pair - keys unique-json
dc={'name':'Deepika',
      'age':20,
        'place':'mysuru'}
dc
# Out:
# {'name': 'Deepika', 'age': 20, 'place': 'mysuru'}

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
dc.keys()
# Out:
# dict_keys(['name', 'age', 'place'])

# %%
dc.values()
# Out:
# dict_values(['Deepika', 20, 'mysuru'])

# %%
for i in range(0,11,2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
for i in range(0,18,3):
    print(i)
# Out:
# 0
# 3
# 6
# 9
# 12
# 15
